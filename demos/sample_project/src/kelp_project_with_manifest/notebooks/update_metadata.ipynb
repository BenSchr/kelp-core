# %%
from databricks.sdk import WorkspaceClient
from databricks.sdk.service import jobs

w = WorkspaceClient()
dbutils = WorkspaceClient().dbutils()

# %%
# job_id = dbutils.widgets.get("job_id")
# kelp_project_file = dbutils.widgets.get("kelp_project_file")
# kelp_target = dbutils.widgets.get("kelp_target")
kelp_manifest_file: str = dbutils.widgets.get("kelp_manifest_file")

# %%
from pyspark.sql import SparkSession

import kelp.catalog as kc

spark = SparkSession.active()

kc.init(manifest_file_path=kelp_manifest_file)
for query in kc.sync_catalog():
    try:
        print(f"Executing query: {query}")
        spark.sql(query)
    except Exception as e:
        print(f"Error executing query: {query}\nException: {e}")
# Out:
# ["ALTER TABLE kelp_catalog.kelp_bronze.bronze_customers SET TAGS ('kelp_managed'='')",
#  "ALTER STREAMING TABLE kelp_catalog.kelp_bronze.bronze_orders ALTER COLUMN order_id COMMENT 'Unique identifier for each order'",
#  "ALTER STREAMING TABLE kelp_catalog.kelp_bronze.bronze_orders SET TAGS ('kelp_managed'='')",
#  "ALTER TABLE kelp_catalog.kelp_silver.silver_customers_cleaned SET TAGS ('kelp_managed'='')"]
